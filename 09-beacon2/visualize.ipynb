# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv('output20240315.txt', sep=',', header=None)
df.columns = ['datetime','temp','hum','light','uv','press','noise','discom','heat','batt']
df = df.iloc[::-1].reset_index(drop=True)
df['datetime'] = pd.to_datetime(df['datetime'], format='%Y/%m/%d %H:%M:%S')
df['doy'] = df['datetime'].dt.dayofyear
df = df[df['light'] != -1]
df
# Out:
#                datetime  temp    hum  light    uv   press  noise  discom  \
# 0   2024-03-13 00:01:06  8.15  73.23      0  0.01  1001.0  36.98   48.33
# 1   2024-03-13 00:16:06  8.06  73.52      0  0.02  1001.2  35.89   48.18
# 2   2024-03-13 00:31:06  8.08  73.29      0  0.01  1001.4  39.42   48.22
# 3   2024-03-13 00:46:06  7.93  73.62      0  0.01  1001.5  36.98   47.97
# 4   2024-03-13 01:01:06  7.89  73.99      0  0.02  1001.9  37.23   47.88
# ..                  ...   ...    ...    ...   ...     ...    ...     ...
# 228 2024-03-15 09:01:06  7.94  69.47    695  0.04  1016.7  39.02   48.25
# 229 2024-03-15 09:16:06  8.30  69.49    713  0.04  1016.6  38.39   48.79
# 230 2024-03-15 09:31:06  8.52  69.18    729  0.04  1016.4  36.72   49.14
# 231 2024-03-15 09:46:06  9.21  68.98    700  0.04  1016.2  37.47   50.18
# 232 2024-03-15 10:01:07  9.31  68.89    713  0.04  1016.2  36.72   50.33
#
#       heat   batt  doy
# 0    11.73  2.555   73
# 1    11.68  2.555   73
# 2    11.69  2.555   73
# 3    11.60  2.555   73
# 4    11.63  2.555   73
# ..     ...    ...  ...
# 228  11.11  2.548   75
# 229  11.33  2.552   75
# 230  11.42  2.555   75
# 231  11.81  2.559   75
# 232  11.87  2.555   75
#
# [233 rows x 11 columns]

# %%
for col in df.columns[1:-1]:
    plt.figure(figsize=(10,3))
    plt.plot(df['datetime'], df[col], label=col)
    plt.xticks(df['datetime'][::24*4], rotation=90)
    plt.legend()
    plt.show()
